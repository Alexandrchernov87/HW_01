# %% [markdown]
# ## Угадываем рандомное число

# %%
import game

# %%
random_predict(88)
# Out:
# 5

# %% [markdown]
# ## Проверка алгоритма.

# %%
from check import score_game
from check import random_predict

# %%
score_game(random_predict)
# Out:
# [2,
#  6,
#  4,
#  5,
#  1,
#  3,
#  5,
#  6,
#  6,
#  6,
#  6,
#  5,
#  6,
#  5,
#  6,
#  6,
#  6,
#  6,
#  2,
#  6,
#  5,
#  4,
#  6,
#  6,
#  5,
#  5,
#  3,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  5,
#  6,
#  3,
#  4,
#  2,
#  5,
#  6,
#  4,
#  6,
#  5,
#  5,
#  6,
#  4,
#  6,
#  5,
#  5,
#  6,
#  1,
#  3,
#  6,
#  6,
#  6,
#  6,
#  5,
#  6,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  6,
#  5,
#  6,
#  5,
#  5,
#  5,
#  4,
#  2,
#  5,
#  5,
#  6,
#  4,
#  6,
#  4,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  2,
#  4,
#  6,
#  2,
#  5,
#  5,
#  4,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  4,
#  6,
#  4,
#  6,
#  4,
#  4,
#  1,
#  5,
#  5,
#  4,
#  1,
#  6,
#  3,
#  6,
#  6,
#  6,
#  5,
#  5,
#  6,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  3,
#  5,
#  1,
#  6,
#  6,
#  6,
#  6,
#  6,
#  4,
#  3,
#  6,
#  1,
#  6,
#  4,
#  4,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  5,
#  5,
#  6,
#  5,
#  3,
#  3,
#  6,
#  6,
#  5,
#  6,
#  5,
#  4,
#  4,
# ...
